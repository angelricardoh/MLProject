# %%
"""
Notes:
- GarageType variable might be biased. Note that it has a 2types variable making our dummy variables technically incorrect since we dont know which 2 types it is
- PavedDrive: It could be argued that this variable should be numerically categorized rather than turned into dummy variables
"""
# Out:
# '\nNotes:\n- GarageType variable might be biased. Note that it has a 2types variable making our dummy variables technically incorrect since we dont know which 2 types it is\n- PavedDrive: It could be argued that this variable should be numerically categorized rather than turned into dummy variables\n'

# %%
import numpy as np
import pandas as pd

import os
# Matplotlib for visualization
from matplotlib import pyplot as plt


# Seaborn for easier visualization
import seaborn as sns

from scipy import stats
sns.set()

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
#warnings.filterwarnings("ignore")

# %%
# SET ENV VARIABLES
train_csv = 'train.csv'
test_csv = 'test.csv'

# %%
# Read CSV
train_df = pd.read_csv(train_csv)
test_df = pd.read_csv(test_csv)

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
print(train_df.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# # Data Cleaning
#
# Skweness is a measure of symmetry or lack of symmetry.
# A distribution is symmetric if it looks the same to the left and right of the center point.
# Kurtosis is a measure whether the data are heavily-tailed or light-tailed relative to the normal distribution.
#
# It is very difficult to interpret and analyze the data which is skewed. Likewise, a collection of data points that are normally distributed (symmetrical) or nearer to symmetrical are easier for computation and more probable for producing better inferences. Hence, reducing the skewness becomes an important part of the data cleaning process for data scientists.

# %%
sns.distplot(train_df['SalePrice']);
#skewness and kurtosis
print("Skewness: %f" % train_df['SalePrice'].skew())
print("Kurtosis: %f" % train_df['SalePrice'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %% [markdown]
# The variable SalePrice is not normally distributed. This can reduce the accuracy of our ML models since most of them assume a Guassian distribution.
#
# Therfore we make a log transformation, the resulting distribution looks much better.

# %%
train_df['SalePrice_Log'] = np.log1p(train_df['SalePrice'])

sns.distplot(train_df['SalePrice_Log']);
# skewness and kurtosis
print("Skewness: %f" % train_df['SalePrice_Log'].skew())
print("Kurtosis: %f" % train_df['SalePrice_Log'].kurt())
# Out:
# Skewness: 0.121347
# Kurtosis: 0.809519

# %%
train_df.shape
test_df.shape
# Out:
# (1459, 80)

# %% [markdown]
# ### Numerical features vs categorial features

# %%
numerical_feats = train_df.dtypes[train_df.dtypes != "object"].index
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = train_df.dtypes[train_df.dtypes == "object"].index
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  39
# Number of Categorical features:  43

# %%
total = train_df.isnull().sum().sort_values(ascending=False)
percent = (train_df.isnull().sum()/train_df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageQual       81  0.055479
# GarageCond       81  0.055479
# GarageFinish     81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# RoofStyle         0  0.000000

# %% [markdown]
# # Data Preprocessing
#
# Filling missing values For a few columns there is lots of NaN entries. However, reading the data description we find this is not missing data: For PoolQC, NaN is not missing data but means no pool, likewise for Fence, FireplaceQu etc.
#
# First we get rid of NA or nan values in numerical columns and use its average. We convert categorical columns to numerical columns as 1-hot vectors to get a better understanding of which categories contribute to a more expensive or less expensive houses.

# %%
class HousePreprocessor():
    def __init__(self, verbose=True):
        self.verbose = verbose
        # Cnvrt disp Vars
        self.disp_cats = [('Electrical', 'SBrkr'), ('BsmtFinType2', 'Unf')]
        
        # Cnvrt Relative Vars
        rating_order_map = {
            'Po': 0,
            'Fa': 1,
            'TA': 2,
            'Gd': 3,
            'Ex': 4,
            'NA': 'NA',
            np.nan: 'NA'
        }

        basement_exposure_map = {
            'No': 0,
            'Mn': 1,
            'Av': 2,
            'Gd': 3,
            'NA': 'NA',
            np.nan: 'NA'
        }

        basement_finish_map = {
            'Unf': 0,
            'LwQ': 1,
            'Rec': 2,
            'BLQ': 3,
            'ALQ': 4,
            'GLQ': 5,
            'NA': 'NA',
            np.nan: 'NA'
        }

        functional_rating = {
            'Sal': 0,
            'Sev': 1,
            'Maj2': 2,
            'Maj1': 3,
            'Mod': 4,
            'Min2': 5,
            'Min1': 6,
            'Typ': 7,
            'NA': 'NA',
            np.nan: 'NA'
        }

        garage_finish_rating = {
            'Unf': 0,
            'RFn': 1,
            'Fin': 2,
            'NA': 'NA',
            np.nan: 'NA'
        }

        fence_quality_rating = {
            "MnWw": 0,
            "GdWo": 1,
            "MnPrv": 2,
            "GdPrv": 3,
            "NA": "NA",
            np.nan: 'NA'
        }

        bool_map = {
            'N': 0,
            'Y': 1
        }

        self.relative_categories = (
            [(cat, rating_order_map) for cat in ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond', 'PoolQC']] + 
            [(cat, basement_exposure_map) for cat in ['BsmtExposure']] +
            [(cat, basement_finish_map) for cat in ['BsmtFinType1']] +
            [(cat, functional_rating) for cat in ['Functional']] +
            [(cat, garage_finish_rating) for cat in ['GarageFinish']] +
            [(cat, fence_quality_rating) for cat in ['Fence']] +
            [(cat, bool_map) for cat in ['CentralAir']]
        )
        
        # Cyclical Vars
        self.cyclical_features = ['MoSold']

        # Dummy Vars
        self.dummy_vars_to_append = ['MSSubClass']
        
    def process(self, df):
        df = self.__cnvrt_disp_class_vars__(df)
        df = self.__cnvrt_relative_cats__(df)
        df = self.__cnvrt_cyclical_vars__(df)
        
        self.__log_remaining_category_vars__(df)
        
        df =  self.__add_dummy_vars__(df)
        
        df = self.__cnvrt_na_to_avg__(df)
        
        return df
    
    def __cnvrt_disp_class_vars__(self, df):
        # Convert Disproportionate Classification Variables
        """
        NOTE: The electrical variable is disproportionately SBrkr. As a result, we will convert Electrical to a boolean of SBrkr vs Not SBrkr rather than creating more variables

        SBrkr - 1334 (91.5%)
        FuseA - 1    (0.05%)
        FuseF - 94   (6.5%)
        FuseP - 27   (1.8%)
        Mix   - 3    (0.25%)

        NOTE: The electrical variable is disproportionately SBrkr. As a result, we will convert Electrical to a boolean of SBrkr vs Not SBrkr rather than creating more variables

        GLQ - 14
        ALQ - 19
        BLQ - 33
        Rec - 54
        LwQ - 46
        Unf - 1256
        NA - 38


        Note: An argument could be made to do the same for BsmtExposure, though we have decided against converting it into a boolean variable

        GD - 134
        Av - 221
        Mn - 114
        No - 953
        NA - 38

        """       
        for cat, key in self.disp_cats:
            df[cat] = [1 if e == key else 0 for e in df[cat]]
            
        return df
            
    def __cnvrt_relative_cats__(self, df):
        # Convert Relative Categorical into numerical
        for cat, map in self.relative_categories:
            num_na = len([i for i in df[cat] if i is np.nan])
            df[cat] = [map[rating] for rating in df[cat]]
            cat_na = f'{cat}_NA'

            # Create Boolean NA Column
            df[cat_na] = [1 if v == 'NA' else 0 for v in df[cat]]

            assert(num_na == sum(df[cat_na]))

            # Convert NA to average (IS THIS REALLY THE BEST STRATEGY?)
            avg = np.average([i for i in df[cat] if i != 'NA'])
            df[cat] = [i if i != 'NA' else avg for i in df[cat]]
        return df
            
    def __cnvrt_cyclical_vars__(self, df):
        # Convert to cyclical (See for more information)
        for f in self.cyclical_features:
            df[f'{f}_sin'] = np.sin(df[f])
            df[f'{f}_cos'] = np.cos(df[f])
            df.drop(f, 1)
            
        return df
            
    def __log_remaining_category_vars__(self, df):
        if self.verbose:
            # Decide which categorical variables you want to use
            # TODO: Convert to bar chart
            for col_name in df.columns:
                if df[col_name].dtypes == 'object':
                    unique_cat = len(df[col_name].unique())
                    print(f'Feature {col_name} has {unique_cat} unique categories')
            
    def __add_dummy_vars__(self, df):           
        dummy_list = [col for col in df.columns if df[col].dtypes == 'object']
        dummy_list = dummy_list + self.dummy_vars_to_append
        
        for cat in dummy_list:
            dummies = pd.get_dummies(df[cat], prefix=cat, dummy_na=True)
            df = df.drop(cat, 1)
            df = pd.concat([df, dummies], axis=1)
            
        return df
    
    def __cnvrt_na_to_avg__(self, df):
        # NOTE: Since Garage YR blt has NA values, we have decided to deal with this by using the average year as the NA value 
        # (IS THIS REALLY THE BEST STRATEGY?)
        cols_with_na = df.isnull().sum().sort_values(ascending=False)
        cols_with_na = list(cols_with_na[cols_with_na > 0].keys())
        
        for col in cols_with_na:
            if self.verbose:
                print(f"Converting nan's in {col} to avg of {col}")
            
            avg = np.average([i for i in df[col] if not np.isnan(i)])
            df[col] = [avg if np.isnan(i) else i for i in df[col]]
        
        cols_with_na = df.isnull().sum().sort_values(ascending=False)
        cols_with_na = cols_with_na[cols_with_na > 0]
        assert 0 == cols_with_na.shape[0]
        
        return df

# %%
hp = HousePreprocessor()
train_df = hp.process(train_df)
print("-------------------------")
test_df = hp.process(test_df)
# Out:
# Feature MSZoning has 5 unique categories
# Feature Street has 2 unique categories
# Feature Alley has 3 unique categories
# Feature LotShape has 4 unique categories
# Feature LandContour has 4 unique categories
# Feature Utilities has 2 unique categories
# Feature LotConfig has 5 unique categories
# Feature LandSlope has 3 unique categories
# Feature Neighborhood has 25 unique categories
# Feature Condition1 has 9 unique categories
# Feature Condition2 has 8 unique categories
# Feature BldgType has 5 unique categories
# Feature HouseStyle has 8 unique categories
# Feature RoofStyle has 6 unique categories
# Feature RoofMatl has 8 unique categories
# Feature Exterior1st has 15 unique categories
# Feature Exterior2nd has 16 unique categories
# Feature MasVnrType has 5 unique categories
# Feature Foundation has 6 unique categories
# Feature Heating has 6 unique categories
# Feature GarageType has 7 unique categories
# Feature PavedDrive has 3 unique categories
# Feature MiscFeature has 5 unique categories
# Feature SaleType has 9 unique categories
# Feature SaleCondition has 6 unique categories
# Converting nan's in LotFrontage to avg of LotFrontage
# Converting nan's in GarageYrBlt to avg of GarageYrBlt
# Converting nan's in MasVnrArea to avg of MasVnrArea
# -------------------------
# Feature MSZoning has 6 unique categories
# Feature Street has 2 unique categories
# Feature Alley has 3 unique categories
# Feature LotShape has 4 unique categories
# Feature LandContour has 4 unique categories
# Feature Utilities has 2 unique categories
# Feature LotConfig has 5 unique categories
# Feature LandSlope has 3 unique categories
# Feature Neighborhood has 25 unique categories
# Feature Condition1 has 9 unique categories
# Feature Condition2 has 5 unique categories
# Feature BldgType has 5 unique categories
# Feature HouseStyle has 7 unique categories
# Feature RoofStyle has 6 unique categories
# Feature RoofMatl has 4 unique categories
# Feature Exterior1st has 14 unique categories
# Feature Exterior2nd has 16 unique categories
# Feature MasVnrType has 5 unique categories
# Feature Foundation has 6 unique categories
# Feature Heating has 4 unique categories
# Feature GarageType has 7 unique categories
# Feature PavedDrive has 3 unique categories
# Feature MiscFeature has 4 unique categories
# Feature SaleType has 10 unique categories
# Feature SaleCondition has 6 unique categories
# Converting nan's in LotFrontage to avg of LotFrontage
# Converting nan's in GarageYrBlt to avg of GarageYrBlt
# Converting nan's in MasVnrArea to avg of MasVnrArea
# Converting nan's in BsmtFullBath to avg of BsmtFullBath
# Converting nan's in BsmtHalfBath to avg of BsmtHalfBath
# Converting nan's in GarageArea to avg of GarageArea
# Converting nan's in GarageCars to avg of GarageCars
# Converting nan's in TotalBsmtSF to avg of TotalBsmtSF
# Converting nan's in BsmtUnfSF to avg of BsmtUnfSF
# Converting nan's in BsmtFinSF2 to avg of BsmtFinSF2
# Converting nan's in BsmtFinSF1 to avg of BsmtFinSF1

# %% [markdown]
# Make sure we get rid of null and nan values

# %%
train_df.isnull().sum().sum()
# Out:
# 0

# %%
numerical_feats = train_df.dtypes[train_df.dtypes != "object"].index
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = train_df.dtypes[train_df.dtypes == "object"].index
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  286
# Number of Categorical features:  0

# %% [markdown]
# Data Analysis

# %%
sns.distplot(train_df['SalePrice']);
#skewness and kurtosis
print("Skewness: %f" % train_df['SalePrice'].skew())
print("Kurtosis: %f" % train_df['SalePrice'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %% [markdown]
# The variable SalePrice is not normally distributed. This can reduce the accuracy of our ML models since most of them assume a Guassian distribution.
# Therfore we make a log transformation, the resulting distribution looks much better.

# %%
train_df['SalePrice_Log'] = np.log1p(train_df['SalePrice'])

sns.distplot(train_df['SalePrice_Log']);
# skewness and kurtosis
print("Skewness: %f" % train_df['SalePrice_Log'].skew())
print("Kurtosis: %f" % train_df['SalePrice_Log'].kurt())
# Out:
# Skewness: 0.121347
# Kurtosis: 0.809519

# %%
for col in numerical_feats:
    print(col)
    print("Skewness: %f" % train_df[col].skew())
    print("Kurtosis: %f" % train_df[col].kurt())
    print("*"*50)
# Out:
# Id
# Skewness: 0.000000
# Kurtosis: -1.200000
# **************************************************
# LotFrontage
# Skewness: 2.384950
# Kurtosis: 21.848165
# **************************************************
# LotArea
# Skewness: 12.207688
# Kurtosis: 203.243271
# **************************************************
# OverallQual
# Skewness: 0.216944
# Kurtosis: 0.096293
# **************************************************
# OverallCond
# Skewness: 0.693067
# Kurtosis: 1.106413
# **************************************************
# YearBuilt
# Skewness: -0.613461
# Kurtosis: -0.439552
# **************************************************
# YearRemodAdd
# Skewness: -0.503562
# Kurtosis: -1.272245
# **************************************************
# MasVnrArea
# Skewness: 2.676412
# Kurtosis: 10.154316
# **************************************************
# ExterQual
# Skewness: 0.825988
# Kurtosis: 0.060816
# **************************************************
# ExterCond
# Skewness: 1.397219
# Kurtosis: 6.100074
# **************************************************
# BsmtQual
# Skewness: 0.289689
# Kurtosis: -0.295211
# **************************************************
# BsmtCond
# Skewness: 0.000709
# Kurtosis: 11.970452
# **************************************************
# BsmtExposure
# Skewness: 1.190469
# Kurtosis: -0.107894
# **************************************************
# BsmtFinType1
# Skewness: -0.179545
# Kurtosis: -1.577961
# **************************************************
# BsmtFinSF1
# Skewness: 1.685503
# Kurtosis: 11.118236
# **************************************************
# BsmtFinType2
# Skewness: -2.080427
# Kurtosis: 2.331366
# **************************************************
# BsmtFinSF2
# Skewness: 4.255261
# Kurtosis: 20.113338
# **************************************************
# BsmtUnfSF
# Skewness: 0.920268
# Kurtosis: 0.474994
# **************************************************
# TotalBsmtSF
# Skewness: 1.524255
# Kurtosis: 13.250483
# **************************************************
# HeatingQC
# Skewness: -0.540458
# Kurtosis: -1.165044
# **************************************************
# CentralAir
# Skewness: -3.530386
# Kurtosis: 10.477974
# **************************************************
# Electrical
# Skewness: -2.949513
# Kurtosis: 6.708815
# **************************************************
# 1stFlrSF
# Skewness: 1.376757
# Kurtosis: 5.745841
# **************************************************
# 2ndFlrSF
# Skewness: 0.813030
# Kurtosis: -0.553464
# **************************************************
# LowQualFinSF
# Skewness: 9.011341
# Kurtosis: 83.234817
# **************************************************
# GrLivArea
# Skewness: 1.366560
# Kurtosis: 4.895121
# **************************************************
# BsmtFullBath
# Skewness: 0.596067
# Kurtosis: -0.839098
# **************************************************
# BsmtHalfBath
# Skewness: 4.103403
# Kurtosis: 16.396642
# **************************************************
# FullBath
# Skewness: 0.036562
# Kurtosis: -0.857043
# **************************************************
# HalfBath
# Skewness: 0.675897
# Kurtosis: -1.076927
# **************************************************
# BedroomAbvGr
# Skewness: 0.211790
# Kurtosis: 2.230875
# **************************************************
# KitchenAbvGr
# Skewness: 4.488397
# Kurtosis: 21.532404
# **************************************************
# KitchenQual
# Skewness: 0.386765
# Kurtosis: -0.247537
# **************************************************
# TotRmsAbvGrd
# Skewness: 0.676341
# Kurtosis: 0.880762
# **************************************************
# Functional
# Skewness: -4.912214
# Kurtosis: 25.900429
# **************************************************
# Fireplaces
# Skewness: 0.649565
# Kurtosis: -0.217237
# **************************************************
# FireplaceQu
# Skewness: -1.241599
# Kurtosis: 5.617354
# **************************************************
# GarageYrBlt
# Skewness: -0.668175
# Kurtosis: -0.266503
# **************************************************
# GarageFinish
# Skewness: 0.357330
# Kurtosis: -1.310134
# **************************************************
# GarageCars
# Skewness: -0.342549
# Kurtosis: 0.220998
# **************************************************
# GarageArea
# Skewness: 0.179981
# Kurtosis: 0.917067
# **************************************************
# GarageQual
# Skewness: -1.347180
# Kurtosis: 28.295621
# **************************************************
# GarageCond
# Skewness: -3.252885
# Kurtosis: 39.518642
# **************************************************
# WoodDeckSF
# Skewness: 1.541376
# Kurtosis: 2.992951
# **************************************************
# OpenPorchSF
# Skewness: 2.364342
# Kurtosis: 8.490336
# **************************************************
# EnclosedPorch
# Skewness: 3.089872
# Kurtosis: 10.430766
# **************************************************
# 3SsnPorch
# Skewness: 10.304342
# Kurtosis: 123.662379
# **************************************************
# ScreenPorch
# Skewness: 4.122214
# Kurtosis: 18.439068
# **************************************************
# PoolArea
# Skewness: 14.828374
# Kurtosis: 223.268499
# **************************************************
# PoolQC
# Skewness: -7.603388
# Kurtosis: 372.039291
# **************************************************
# Fence
# Skewness: -1.072715
# Kurtosis: 13.395175
# **************************************************
# MiscVal
# Skewness: 24.476794
# Kurtosis: 701.003342
# **************************************************
# MoSold
# Skewness: 0.212053
# Kurtosis: -0.404109
# **************************************************
# YrSold
# Skewness: 0.096269
# Kurtosis: -1.190601
# **************************************************
# SalePrice
# Skewness: 1.882876
# Kurtosis: 6.536282
# **************************************************
# SalePrice_Log
# Skewness: 0.121347
# Kurtosis: 0.809519
# **************************************************
# ExterQual_NA
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# ExterCond_NA
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# BsmtQual_NA
# Skewness: 6.046534
# Kurtosis: 34.607975
# **************************************************
# BsmtCond_NA
# Skewness: 6.046534
# Kurtosis: 34.607975
# **************************************************
# HeatingQC_NA
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# KitchenQual_NA
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# FireplaceQu_NA
# Skewness: 0.109867
# Kurtosis: -1.990658
# **************************************************
# GarageQual_NA
# Skewness: 3.887735
# Kurtosis: 13.132467
# **************************************************
# GarageCond_NA
# Skewness: 3.887735
# Kurtosis: 13.132467
# **************************************************
# PoolQC_NA
# Skewness: -14.352680
# Kurtosis: 204.279269
# **************************************************
# BsmtExposure_NA
# Skewness: 5.959928
# Kurtosis: 33.566727
# **************************************************
# BsmtFinType1_NA
# Skewness: 6.046534
# Kurtosis: 34.607975
# **************************************************
# Functional_NA
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# GarageFinish_NA
# Skewness: 3.887735
# Kurtosis: 13.132467
# **************************************************
# Fence_NA
# Skewness: -1.561755
# Kurtosis: 0.439678
# **************************************************
# CentralAir_NA
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# MoSold_sin
# Skewness: 0.184323
# Kurtosis: -1.470240
# **************************************************
# MoSold_cos
# Skewness: -0.310344
# Kurtosis: -1.394694
# **************************************************
# MSZoning_C (all)
# Skewness: 11.970851
# Kurtosis: 141.495111
# **************************************************
# MSZoning_FV
# Skewness: 4.421345
# Kurtosis: 17.572362
# **************************************************
# MSZoning_RH
# Skewness: 9.404402
# Kurtosis: 86.561346
# **************************************************
# MSZoning_RL
# Skewness: -1.413324
# Kurtosis: -0.002521
# **************************************************
# MSZoning_RM
# Skewness: 1.969960
# Kurtosis: 1.883321
# **************************************************
# MSZoning_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Street_Grvl
# Skewness: 15.518770
# Kurtosis: 239.159822
# **************************************************
# Street_Pave
# Skewness: -15.518770
# Kurtosis: 239.159822
# **************************************************
# Street_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Alley_Grvl
# Skewness: 5.127326
# Kurtosis: 24.322785
# **************************************************
# Alley_Pave
# Skewness: 5.718902
# Kurtosis: 30.747957
# **************************************************
# Alley_nan
# Skewness: -3.624557
# Kurtosis: 11.152692
# **************************************************
# LotShape_IR1
# Skewness: 0.716579
# Kurtosis: -1.488556
# **************************************************
# LotShape_IR2
# Skewness: 5.718902
# Kurtosis: 30.747957
# **************************************************
# LotShape_IR3
# Skewness: 11.970851
# Kurtosis: 141.495111
# **************************************************
# LotShape_Reg
# Skewness: -0.554962
# Kurtosis: -1.694340
# **************************************************
# LotShape_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# LandContour_Bnk
# Skewness: 4.501258
# Kurtosis: 18.286371
# **************************************************
# LandContour_HLS
# Skewness: 5.127326
# Kurtosis: 24.322785
# **************************************************
# LandContour_Low
# Skewness: 6.136628
# Kurtosis: 35.707111
# **************************************************
# LandContour_Lvl
# Skewness: -2.631832
# Kurtosis: 4.933297
# **************************************************
# LandContour_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Utilities_AllPub
# Skewness: -38.209946
# Kurtosis: 1460.000000
# **************************************************
# Utilities_NoSeWa
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Utilities_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# LotConfig_Corner
# Skewness: 1.666359
# Kurtosis: 0.777815
# **************************************************
# LotConfig_CulDSac
# Skewness: 3.553402
# Kurtosis: 10.641243
# **************************************************
# LotConfig_FR2
# Skewness: 5.306122
# Kurtosis: 26.190808
# **************************************************
# LotConfig_FR3
# Skewness: 19.045943
# Kurtosis: 361.242801
# **************************************************
# LotConfig_Inside
# Skewness: -0.983999
# Kurtosis: -1.033164
# **************************************************
# LotConfig_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# LandSlope_Gtl
# Skewness: -3.975784
# Kurtosis: 13.825799
# **************************************************
# LandSlope_Mod
# Skewness: 4.421345
# Kurtosis: 17.572362
# **************************************************
# LandSlope_Sev
# Skewness: 10.466218
# Kurtosis: 107.689228
# **************************************************
# LandSlope_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Neighborhood_Blmngtn
# Skewness: 9.113988
# Kurtosis: 81.175974
# **************************************************
# Neighborhood_Blueste
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Neighborhood_BrDale
# Skewness: 9.404402
# Kurtosis: 86.561346
# **************************************************
# Neighborhood_BrkSide
# Skewness: 4.717999
# Kurtosis: 20.287301
# **************************************************
# Neighborhood_ClearCr
# Skewness: 7.018804
# Kurtosis: 47.328445
# **************************************************
# Neighborhood_CollgCr
# Skewness: 2.619529
# Kurtosis: 4.868601
# **************************************************
# Neighborhood_Crawfor
# Skewness: 5.071142
# Kurtosis: 23.749008
# **************************************************
# Neighborhood_Edwards
# Skewness: 3.420170
# Kurtosis: 9.710861
# **************************************************
# Neighborhood_Gilbert
# Skewness: 3.945910
# Kurtosis: 13.588817
# **************************************************
# Neighborhood_IDOTRR
# Skewness: 6.046534
# Kurtosis: 34.607975
# **************************************************
# Neighborhood_MeadowV
# Skewness: 9.113988
# Kurtosis: 81.175974
# **************************************************
# Neighborhood_Mitchel
# Skewness: 5.185159
# Kurtosis: 24.920013
# **************************************************
# Neighborhood_NAmes
# Skewness: 1.917976
# Kurtosis: 1.680933
# **************************************************
# Neighborhood_NPkVill
# Skewness: 12.631556
# Kurtosis: 157.772330
# **************************************************
# Neighborhood_NWAmes
# Skewness: 4.133731
# Kurtosis: 15.108430
# **************************************************
# Neighborhood_NoRidge
# Skewness: 5.718902
# Kurtosis: 30.747957
# **************************************************
# Neighborhood_NridgHt
# Skewness: 4.006206
# Kurtosis: 14.068957
# **************************************************
# Neighborhood_OldTown
# Skewness: 3.166203
# Kurtosis: 8.035845
# **************************************************
# Neighborhood_SWISU
# Skewness: 7.451946
# Kurtosis: 53.604931
# **************************************************
# Neighborhood_Sawyer
# Skewness: 4.100935
# Kurtosis: 14.837994
# **************************************************
# Neighborhood_SawyerW
# Skewness: 4.672550
# Kurtosis: 19.859931
# **************************************************
# Neighborhood_Somerst
# Skewness: 3.750765
# Kurtosis: 12.084789
# **************************************************
# Neighborhood_StoneBr
# Skewness: 7.451946
# Kurtosis: 53.604931
# **************************************************
# Neighborhood_Timber
# Skewness: 5.959928
# Kurtosis: 33.566727
# **************************************************
# Neighborhood_Veenker
# Skewness: 11.401839
# Kurtosis: 128.177514
# **************************************************
# Neighborhood_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Condition1_Artery
# Skewness: 5.244728
# Kurtosis: 25.542157
# **************************************************
# Condition1_Feedr
# Skewness: 3.887735
# Kurtosis: 13.132467
# **************************************************
# Condition1_Norm
# Skewness: -2.113743
# Kurtosis: 2.471292
# **************************************************
# Condition1_PosA
# Skewness: 13.411750
# Kurtosis: 178.119028
# **************************************************
# Condition1_PosN
# Skewness: 8.602751
# Kurtosis: 72.106099
# **************************************************
# Condition1_RRAe
# Skewness: 11.401839
# Kurtosis: 128.177514
# **************************************************
# Condition1_RRAn
# Skewness: 7.299413
# Kurtosis: 51.351778
# **************************************************
# Condition1_RRNe
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Condition1_RRNn
# Skewness: 17.017590
# Kurtosis: 287.992875
# **************************************************
# Condition1_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Condition2_Artery
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Condition2_Feedr
# Skewness: 15.518770
# Kurtosis: 239.159822
# **************************************************
# Condition2_Norm
# Skewness: -9.723062
# Kurtosis: 92.664862
# **************************************************
# Condition2_PosA
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Condition2_PosN
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Condition2_RRAe
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Condition2_RRAn
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Condition2_RRNn
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Condition2_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# BldgType_1Fam
# Skewness: -1.812955
# Kurtosis: 1.288570
# **************************************************
# BldgType_2fmCon
# Skewness: 6.649007
# Kurtosis: 42.267186
# **************************************************
# BldgType_Duplex
# Skewness: 5.016528
# Kurtosis: 23.197328
# **************************************************
# BldgType_Twnhs
# Skewness: 5.572039
# Kurtosis: 29.087460
# **************************************************
# BldgType_TwnhsE
# Skewness: 3.148345
# Kurtosis: 7.922927
# **************************************************
# BldgType_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# HouseStyle_1.5Fin
# Skewness: 2.571385
# Kurtosis: 4.618345
# **************************************************
# HouseStyle_1.5Unf
# Skewness: 10.074915
# Kurtosis: 99.640410
# **************************************************
# HouseStyle_1Story
# Skewness: 0.010970
# Kurtosis: -2.002625
# **************************************************
# HouseStyle_2.5Fin
# Skewness: 13.411750
# Kurtosis: 178.119028
# **************************************************
# HouseStyle_2.5Unf
# Skewness: 11.401839
# Kurtosis: 128.177514
# **************************************************
# HouseStyle_2Story
# Skewness: 0.849001
# Kurtosis: -1.280953
# **************************************************
# HouseStyle_SFoyer
# Skewness: 6.046534
# Kurtosis: 34.607975
# **************************************************
# HouseStyle_SLvl
# Skewness: 4.421345
# Kurtosis: 17.572362
# **************************************************
# HouseStyle_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# RoofStyle_Flat
# Skewness: 10.466218
# Kurtosis: 107.689228
# **************************************************
# RoofStyle_Gable
# Skewness: -1.363893
# Kurtosis: -0.139990
# **************************************************
# RoofStyle_Gambrel
# Skewness: 11.401839
# Kurtosis: 128.177514
# **************************************************
# RoofStyle_Hip
# Skewness: 1.534060
# Kurtosis: 0.353824
# **************************************************
# RoofStyle_Mansard
# Skewness: 14.352680
# Kurtosis: 204.279269
# **************************************************
# RoofStyle_Shed
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# RoofStyle_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# RoofMatl_ClyTile
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# RoofMatl_CompShg
# Skewness: -7.299413
# Kurtosis: 51.351778
# **************************************************
# RoofMatl_Membran
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# RoofMatl_Metal
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# RoofMatl_Roll
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# RoofMatl_Tar&Grv
# Skewness: 11.401839
# Kurtosis: 128.177514
# **************************************************
# RoofMatl_WdShake
# Skewness: 17.017590
# Kurtosis: 287.992875
# **************************************************
# RoofMatl_WdShngl
# Skewness: 15.518770
# Kurtosis: 239.159822
# **************************************************
# RoofMatl_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Exterior1st_AsbShng
# Skewness: 8.376038
# Kurtosis: 68.251510
# **************************************************
# Exterior1st_AsphShn
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Exterior1st_BrkComm
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Exterior1st_BrkFace
# Skewness: 5.127326
# Kurtosis: 24.322785
# **************************************************
# Exterior1st_CBlock
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Exterior1st_CemntBd
# Skewness: 4.584890
# Kurtosis: 19.047304
# **************************************************
# Exterior1st_HdBoard
# Skewness: 1.940008
# Kurtosis: 1.766047
# **************************************************
# Exterior1st_ImStucc
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Exterior1st_MetalSd
# Skewness: 1.954900
# Kurtosis: 1.824131
# **************************************************
# Exterior1st_Plywood
# Skewness: 3.258868
# Kurtosis: 8.632040
# **************************************************
# Exterior1st_Stone
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Exterior1st_Stucco
# Skewness: 7.451946
# Kurtosis: 53.604931
# **************************************************
# Exterior1st_VinylSd
# Skewness: 0.617015
# Kurtosis: -1.621516
# **************************************************
# Exterior1st_Wd Sdng
# Skewness: 2.064075
# Kurtosis: 2.263504
# **************************************************
# Exterior1st_WdShing
# Skewness: 7.299413
# Kurtosis: 51.351778
# **************************************************
# Exterior1st_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Exterior2nd_AsbShng
# Skewness: 8.376038
# Kurtosis: 68.251510
# **************************************************
# Exterior2nd_AsphShn
# Skewness: 22.015094
# Kurtosis: 483.326474
# **************************************************
# Exterior2nd_Brk Cmn
# Skewness: 14.352680
# Kurtosis: 204.279269
# **************************************************
# Exterior2nd_BrkFace
# Skewness: 7.451946
# Kurtosis: 53.604931
# **************************************************
# Exterior2nd_CBlock
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Exterior2nd_CmentBd
# Skewness: 4.628196
# Kurtosis: 19.446832
# **************************************************
# Exterior2nd_HdBoard
# Skewness: 2.055974
# Kurtosis: 2.230080
# **************************************************
# Exterior2nd_ImStucc
# Skewness: 11.970851
# Kurtosis: 141.495111
# **************************************************
# Exterior2nd_MetalSd
# Skewness: 2.000600
# Kurtosis: 2.005147
# **************************************************
# Exterior2nd_Other
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Exterior2nd_Plywood
# Skewness: 2.721147
# Kurtosis: 5.412053
# **************************************************
# Exterior2nd_Stone
# Skewness: 17.017590
# Kurtosis: 287.992875
# **************************************************
# Exterior2nd_Stucco
# Skewness: 7.299413
# Kurtosis: 51.351778
# **************************************************
# Exterior2nd_VinylSd
# Skewness: 0.651840
# Kurtosis: -1.577268
# **************************************************
# Exterior2nd_Wd Sdng
# Skewness: 2.139287
# Kurtosis: 2.580080
# **************************************************
# Exterior2nd_Wd Shng
# Skewness: 5.959928
# Kurtosis: 33.566727
# **************************************************
# Exterior2nd_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# MasVnrType_BrkCmn
# Skewness: 9.723062
# Kurtosis: 92.664862
# **************************************************
# MasVnrType_BrkFace
# Skewness: 0.849001
# Kurtosis: -1.280953
# **************************************************
# MasVnrType_None
# Skewness: -0.373853
# Kurtosis: -1.862787
# **************************************************
# MasVnrType_Stone
# Skewness: 2.918878
# Kurtosis: 6.528790
# **************************************************
# MasVnrType_nan
# Skewness: 13.411750
# Kurtosis: 178.119028
# **************************************************
# Foundation_BrkTil
# Skewness: 2.669410
# Kurtosis: 5.132779
# **************************************************
# Foundation_CBlock
# Skewness: 0.265591
# Kurtosis: -1.932110
# **************************************************
# Foundation_PConc
# Skewness: 0.229117
# Kurtosis: -1.950179
# **************************************************
# Foundation_Slab
# Skewness: 7.613746
# Kurtosis: 56.045907
# **************************************************
# Foundation_Stone
# Skewness: 15.518770
# Kurtosis: 239.159822
# **************************************************
# Foundation_Wood
# Skewness: 22.015094
# Kurtosis: 483.326474
# **************************************************
# Foundation_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# Heating_Floor
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# Heating_GasA
# Skewness: -6.537217
# Kurtosis: 40.791077
# **************************************************
# Heating_GasW
# Skewness: 8.847848
# Kurtosis: 76.389056
# **************************************************
# Heating_Grav
# Skewness: 14.352680
# Kurtosis: 204.279269
# **************************************************
# Heating_OthW
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# Heating_Wall
# Skewness: 19.045943
# Kurtosis: 361.242801
# **************************************************
# Heating_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# GarageType_2Types
# Skewness: 15.518770
# Kurtosis: 239.159822
# **************************************************
# GarageType_Attchd
# Skewness: -0.391218
# Kurtosis: -1.849484
# **************************************************
# GarageType_Basment
# Skewness: 8.602751
# Kurtosis: 72.106099
# **************************************************
# GarageType_BuiltIn
# Skewness: 3.699075
# Kurtosis: 11.699183
# **************************************************
# GarageType_CarPort
# Skewness: 12.631556
# Kurtosis: 157.772330
# **************************************************
# GarageType_Detchd
# Skewness: 1.065652
# Kurtosis: -0.865574
# **************************************************
# GarageType_nan
# Skewness: 3.887735
# Kurtosis: 13.132467
# **************************************************
# PavedDrive_N
# Skewness: 3.649009
# Kurtosis: 11.330789
# **************************************************
# PavedDrive_P
# Skewness: 6.766217
# Kurtosis: 43.841752
# **************************************************
# PavedDrive_Y
# Skewness: -3.045533
# Kurtosis: 7.285251
# **************************************************
# PavedDrive_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# MiscFeature_Gar2
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# MiscFeature_Othr
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# MiscFeature_Shed
# Skewness: 5.185159
# Kurtosis: 24.920013
# **************************************************
# MiscFeature_TenC
# Skewness: 38.209946
# Kurtosis: 1460.000000
# **************************************************
# MiscFeature_nan
# Skewness: -4.911721
# Kurtosis: 22.155352
# **************************************************
# SaleType_COD
# Skewness: 5.572039
# Kurtosis: 29.087460
# **************************************************
# SaleType_CWD
# Skewness: 19.045943
# Kurtosis: 361.242801
# **************************************************
# SaleType_Con
# Skewness: 26.990701
# Kurtosis: 727.494510
# **************************************************
# SaleType_ConLD
# Skewness: 12.631556
# Kurtosis: 157.772330
# **************************************************
# SaleType_ConLI
# Skewness: 17.017590
# Kurtosis: 287.992875
# **************************************************
# SaleType_ConLw
# Skewness: 17.017590
# Kurtosis: 287.992875
# **************************************************
# SaleType_New
# Skewness: 3.012813
# Kurtosis: 7.086747
# **************************************************
# SaleType_Oth
# Skewness: 22.015094
# Kurtosis: 483.326474
# **************************************************
# SaleType_WD
# Skewness: -2.174122
# Kurtosis: 2.730544
# **************************************************
# SaleType_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# SaleCondition_Abnorml
# Skewness: 3.399044
# Kurtosis: 9.566603
# **************************************************
# SaleCondition_AdjLand
# Skewness: 19.045943
# Kurtosis: 361.242801
# **************************************************
# SaleCondition_Alloca
# Skewness: 10.905010
# Kurtosis: 117.079634
# **************************************************
# SaleCondition_Family
# Skewness: 8.376038
# Kurtosis: 68.251510
# **************************************************
# SaleCondition_Normal
# Skewness: -1.672412
# Kurtosis: 0.798054
# **************************************************
# SaleCondition_Partial
# Skewness: 2.965079
# Kurtosis: 6.801009
# **************************************************
# SaleCondition_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************
# MSSubClass_20.0
# Skewness: 0.551899
# Kurtosis: -1.697735
# **************************************************
# MSSubClass_30.0
# Skewness: 4.271593
# Kurtosis: 16.268793
# **************************************************
# MSSubClass_40.0
# Skewness: 19.045943
# Kurtosis: 361.242801
# **************************************************
# MSSubClass_45.0
# Skewness: 10.905010
# Kurtosis: 117.079634
# **************************************************
# MSSubClass_50.0
# Skewness: 2.695038
# Kurtosis: 5.270450
# **************************************************
# MSSubClass_60.0
# Skewness: 1.464543
# Kurtosis: 0.145083
# **************************************************
# MSSubClass_70.0
# Skewness: 4.628196
# Kurtosis: 19.446832
# **************************************************
# MSSubClass_75.0
# Skewness: 9.404402
# Kurtosis: 86.561346
# **************************************************
# MSSubClass_80.0
# Skewness: 4.717999
# Kurtosis: 20.287301
# **************************************************
# MSSubClass_85.0
# Skewness: 8.376038
# Kurtosis: 68.251510
# **************************************************
# MSSubClass_90.0
# Skewness: 5.016528
# Kurtosis: 23.197328
# **************************************************
# MSSubClass_120.0
# Skewness: 3.724711
# Kurtosis: 11.889760
# **************************************************
# MSSubClass_160.0
# Skewness: 4.501258
# Kurtosis: 18.286371
# **************************************************
# MSSubClass_180.0
# Skewness: 11.970851
# Kurtosis: 141.495111
# **************************************************
# MSSubClass_190.0
# Skewness: 6.766217
# Kurtosis: 43.841752
# **************************************************
# MSSubClass_nan
# Skewness: 0.000000
# Kurtosis: 0.000000
# **************************************************

# %%
sns.distplot(train_df['GrLivArea']);
#skewness and kurtosis
print("Skewness: %f" % train_df['GrLivArea'].skew())
print("Kurtosis: %f" % train_df['GrLivArea'].kurt())
# Out:
# Skewness: 1.366560
# Kurtosis: 4.895121

# %%
sns.distplot(train_df['LotArea']);
#skewness and kurtosis
print("Skewness: %f" % train_df['LotArea'].skew())
print("Kurtosis: %f" % train_df['LotArea'].kurt())
# Out:
# Skewness: 12.207688
# Kurtosis: 203.243271

# %% [markdown]
# Fix skewness and kurtosis

# %%
for df in [train_df, test_df]:
    df['GrLivArea_Log'] = np.log(df['GrLivArea'])
    df.drop('GrLivArea', inplace= True, axis = 1)
    df['LotArea_Log'] = np.log(df['LotArea'])
    df.drop('LotArea', inplace= True, axis = 1)
    
numerical_feats = train_df.dtypes[train_df.dtypes != "object"].index

# %%
sns.distplot(train_df['GrLivArea_Log']);
#skewness and kurtosis
print("Skewness: %f" % train_df['GrLivArea_Log'].skew())
print("Kurtosis: %f" % train_df['GrLivArea_Log'].kurt())
# Out:
# Skewness: -0.006995
# Kurtosis: 0.282603

# %%
sns.distplot(train_df['LotArea_Log']);
#skewness and kurtosis
print("Skewness: %f" % train_df['LotArea_Log'].skew())
print("Kurtosis: %f" % train_df['LotArea_Log'].kurt())
# Out:
# Skewness: -0.137994
# Kurtosis: 4.713358

# %% [markdown]
# # Relation of features to target (SalePrice_log) using seaborn.regplot
#
# sns.regplot function allow us to plot the relationship between two variables in a DataFrame which give us an idea about the relationship between all data points of a feature/column versus the SalePrice_log
#
# seaborn.regplot(x, y, axes to draw the plot, color)

# %%
nr_rows = 12
nr_cols = 4
target = 'SalePrice_Log'
colors = sns.color_palette()

fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*3.5,nr_rows*3))

li_num_feats = list(numerical_feats)
li_not_plot = ['Id', 'SalePrice', 'SalePrice_Log']
li_plot_num_feats = [c for c in list(numerical_feats) if c not in li_not_plot]


for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        i = r*nr_cols+c
        if i < len(li_plot_num_feats):
            sns.regplot(train_df[li_plot_num_feats[i]], train_df[target], ax = axs[r][c], color=colors[i % 10])
            stp = stats.pearsonr(train_df[li_plot_num_feats[i]], train_df[target])

            str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
            axs[r][c].set_title(str_title,fontsize=11)
            
plt.tight_layout()    
plt.show()

# %% [markdown]
# ### Correlation
#
# Measuring correlation between two features it is considered a very important step in feature selection since it helps us to predict one attribute from another (dependent vectors) and it can indicate the presence of a casual relationship.
#
# A dataset with small correlation ratios have a high change that Logistic Regression or Linear Regression models might be impacted by Multicollinearity which happens when one predictor variable in a multiple regression model can be linearly predicted from the others with a high degree of accuracy.
#
# Fortunetaly pandas framework include a function DataFrame.corr(method='pearson', min_periods=1) to compute pairwise correlation of columns.

# %%
min_val_corr = 0.6

corr = train_df.corr()
corr_abs = corr.abs()

nr_num_cols = len(numerical_feats)
ser_corr = corr_abs.nlargest(nr_num_cols, target)[target]

cols_abv_corr_limit = list(ser_corr[ser_corr.values > min_val_corr].index)
cols_bel_corr_limit = list(ser_corr[ser_corr.values <= min_val_corr].index)

# %%
print(ser_corr)
print("*"*30)
print("List of numerical features with r above min_val_corr :")
print(cols_abv_corr_limit)
print("*"*30)
print("List of numerical features with r below min_val_corr :")
print(cols_bel_corr_limit)
# Out:
# SalePrice_Log       1.000000
# SalePrice           0.948374
# OverallQual         0.817185
# GrLivArea_Log       0.730255
# GarageCars          0.680625
#                       ...
# SaleType_ConLI      0.003058
# RoofMatl_ClyTile    0.002696
# MoSold_cos          0.001770
# MiscFeature_Gar2    0.001624
# MSSubClass_80.0     0.001134
# Name: SalePrice_Log, Length: 258, dtype: float64
# ******************************
# List of numerical features with r above min_val_corr :
# ['SalePrice_Log', 'SalePrice', 'OverallQual', 'GrLivArea_Log', 'GarageCars', 'ExterQual', 'KitchenQual', 'GarageArea', 'BsmtQual', 'TotalBsmtSF']
# ******************************
# List of numerical features with r below min_val_corr :
# ['1stFlrSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd', 'Foundation_PConc', 'GarageFinish', 'FireplaceQu_NA', 'GarageYrBlt', 'Fireplaces', 'HeatingQC', 'MasVnrArea', 'GarageType_Attchd', 'MSSubClass_60.0', 'LotArea_Log', 'MasVnrType_None', 'GarageType_Detchd', 'BsmtFinSF1', 'Neighborhood_NridgHt', 'CentralAir', 'MSZoning_RM', 'Foundation_CBlock', 'Exterior2nd_VinylSd', 'LotFrontage', 'Exterior1st_VinylSd', 'WoodDeckSF', 'MSSubClass_30.0', 'SaleType_New', 'SaleCondition_Partial', 'GarageFinish_NA', 'GarageType_nan', 'GarageCond_NA', 'GarageQual_NA', 'OpenPorchSF', '2ndFlrSF', 'BsmtExposure', 'HalfBath', 'MasVnrType_Stone', 'Electrical', 'PavedDrive_Y', 'MSZoning_RL', 'BsmtFinType1', 'LotShape_Reg', 'PavedDrive_N', 'Neighborhood_NoRidge', 'HouseStyle_2Story', 'Foundation_BrkTil', 'LotShape_IR1', 'BsmtFullBath', 'Neighborhood_IDOTRR', 'Neighborhood_OldTown', 'MasVnrType_BrkFace', 'GarageType_BuiltIn', 'BsmtUnfSF', 'Neighborhood_Edwards', 'SaleType_WD', 'BedroomAbvGr', 'BsmtCond', 'FireplaceQu', 'BsmtFinType1_NA', 'BsmtCond_NA', 'BsmtQual_NA', 'RoofStyle_Hip', 'BsmtExposure_NA', 'RoofStyle_Gable', 'MSZoning_C (all)', 'Exterior1st_Wd Sdng', 'Neighborhood_StoneBr', 'Exterior2nd_Wd Sdng', 'HouseStyle_1.5Fin', 'Fence_NA', 'GarageQual', 'Neighborhood_BrkSide', 'MSSubClass_50.0', 'Exterior1st_MetalSd', 'Neighborhood_Somerst', 'Exterior2nd_MetalSd', 'Neighborhood_NAmes', 'Alley_Grvl', 'SaleCondition_Abnorml', 'Foundation_Slab', 'GarageCond', 'Neighborhood_MeadowV', 'Heating_Grav', 'EnclosedPorch', 'LotConfig_CulDSac', 'KitchenAbvGr', 'Exterior1st_AsbShng', 'Neighborhood_Timber', 'Functional', 'Heating_GasA', 'Exterior2nd_AsbShng', 'BldgType_1Fam', 'Alley_nan', 'Condition1_Artery', 'Neighborhood_BrDale', 'LotShape_IR2', 'Condition1_Feedr', 'Neighborhood_Sawyer', 'BsmtFinType2', 'ScreenPorch', 'MSZoning_FV', 'RoofMatl_WdShngl', 'Condition1_Norm', 'Neighborhood_CollgCr', 'MSSubClass_90.0', 'BldgType_Duplex', 'MSSubClass_160.0', 'LandContour_Bnk', 'LandContour_HLS', 'BldgType_2fmCon', 'BldgType_Twnhs', 'MSSubClass_180.0', 'HouseStyle_1.5Unf', 'MSSubClass_190.0', 'SaleCondition_Normal', 'MSSubClass_45.0', 'HouseStyle_SFoyer', 'PavedDrive_P', 'Exterior1st_CemntBd', 'MSSubClass_120.0', 'Exterior2nd_CmentBd', 'Fence', 'RoofMatl_CompShg', 'LotConfig_Inside', 'Neighborhood_Crawfor', 'GarageType_CarPort', 'SaleType_COD', 'Exterior1st_BrkComm', 'Neighborhood_Gilbert', 'Heating_Wall', 'MiscFeature_nan', 'Exterior1st_HdBoard', 'HouseStyle_1Story', 'Neighborhood_ClearCr', 'MiscFeature_Shed', 'MSZoning_RH', 'Neighborhood_Veenker', 'PoolQC_NA', 'PoolArea', 'SaleCondition_AdjLand', 'MiscFeature_Othr', 'Condition1_PosN', 'Neighborhood_SWISU', 'Neighborhood_NWAmes', 'Exterior1st_WdShing', 'Exterior2nd_Stucco', 'Street_Grvl', 'Street_Pave', 'MoSold', 'Exterior2nd_Brk Cmn', 'Condition2_Feedr', 'MasVnrType_nan', '3SsnPorch', 'MSSubClass_20.0', 'Condition2_RRNn', 'Heating_Floor', 'Exterior2nd_Wd Shng', 'RoofMatl_WdShake', 'Condition1_PosA', 'Exterior2nd_HdBoard', 'SaleType_ConLD', 'RoofStyle_Gambrel', 'ExterCond', 'SaleCondition_Family', 'Condition2_Norm', 'Exterior2nd_ImStucc', 'Condition1_RRAe', 'Condition2_PosA', 'Exterior1st_Stucco', 'MasVnrType_BrkCmn', 'Condition2_PosN', 'SaleType_Con', 'Exterior2nd_Other', 'Condition2_Artery', 'Neighborhood_Mitchel', 'Exterior1st_Stone', 'SaleType_Oth', 'Neighborhood_Blmngtn', 'LandContour_Low', 'LowQualFinSF', 'MSSubClass_85.0', 'LotShape_IR3', 'SaleType_ConLw', 'YrSold', 'OverallCond', 'LandSlope_Gtl', 'PoolQC', 'MoSold_sin', 'Neighborhood_SawyerW', 'Exterior1st_AsphShn', 'HouseStyle_2.5Fin', 'MSSubClass_70.0', 'Neighborhood_NPkVill', 'GarageType_Basment', 'Exterior1st_CBlock', 'Exterior2nd_CBlock', 'Exterior1st_BrkFace', 'Exterior1st_ImStucc', 'LandSlope_Mod', 'RoofStyle_Shed', 'MiscFeature_TenC', 'Heating_OthW', 'Heating_GasW', 'BldgType_TwnhsE', 'LandSlope_Sev', 'HouseStyle_2.5Unf', 'SaleCondition_Alloca', 'Exterior2nd_AsphShn', 'RoofMatl_Membran', 'Exterior2nd_Plywood', 'RoofStyle_Flat', 'SaleType_CWD ...

# %%
def plot_corr_matrix(df, nr_c, targ) :
    
    corr = df.corr()
    corr_abs = corr.abs()
    cols = corr_abs.nlargest(nr_c, targ)[targ].index
    cm = np.corrcoef(df[cols].values.T)

    plt.figure(figsize=(nr_c/1.5, nr_c/1.5))
    sns.set(font_scale=1.25)
    sns.heatmap(cm, linewidths=1.5, annot=True, square=True, 
                fmt='.2f', annot_kws={'size': 10}, 
                yticklabels=cols.values, xticklabels=cols.values
               )
    plt.show()

# %%
nr_feats = len(cols_abv_corr_limit)

# %%
plot_corr_matrix(train_df, nr_feats, target)

# %% [markdown]
# Conclusion from EDA on numerical columns:
#
# We see that for some features like 'OverallQual' there is a strong linear correlation (0.81) to the target. For other features like 'MSSubClass' or 'MiscFeature' the correlation is very weak. For this kernel I decided to use only those features for prediction that have a correlation larger than a threshold value to SalePrice. This threshold value can be choosen in the global settings : min_val_corr
#
# With the default threshold for min_val_corr = 0.6, these features are dropped in Data Wrangling:

# %%
print(cols_bel_corr_limit)
# Out:
# ['1stFlrSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd', 'Foundation_PConc', 'GarageFinish', 'FireplaceQu_NA', 'GarageYrBlt', 'Fireplaces', 'HeatingQC', 'MasVnrArea', 'GarageType_Attchd', 'MSSubClass_60.0', 'LotArea_Log', 'MasVnrType_None', 'GarageType_Detchd', 'BsmtFinSF1', 'Neighborhood_NridgHt', 'CentralAir', 'MSZoning_RM', 'Foundation_CBlock', 'Exterior2nd_VinylSd', 'LotFrontage', 'Exterior1st_VinylSd', 'WoodDeckSF', 'MSSubClass_30.0', 'SaleType_New', 'SaleCondition_Partial', 'GarageFinish_NA', 'GarageType_nan', 'GarageCond_NA', 'GarageQual_NA', 'OpenPorchSF', '2ndFlrSF', 'BsmtExposure', 'HalfBath', 'MasVnrType_Stone', 'Electrical', 'PavedDrive_Y', 'MSZoning_RL', 'BsmtFinType1', 'LotShape_Reg', 'PavedDrive_N', 'Neighborhood_NoRidge', 'HouseStyle_2Story', 'Foundation_BrkTil', 'LotShape_IR1', 'BsmtFullBath', 'Neighborhood_IDOTRR', 'Neighborhood_OldTown', 'MasVnrType_BrkFace', 'GarageType_BuiltIn', 'BsmtUnfSF', 'Neighborhood_Edwards', 'SaleType_WD', 'BedroomAbvGr', 'BsmtCond', 'FireplaceQu', 'BsmtFinType1_NA', 'BsmtCond_NA', 'BsmtQual_NA', 'RoofStyle_Hip', 'BsmtExposure_NA', 'RoofStyle_Gable', 'MSZoning_C (all)', 'Exterior1st_Wd Sdng', 'Neighborhood_StoneBr', 'Exterior2nd_Wd Sdng', 'HouseStyle_1.5Fin', 'Fence_NA', 'GarageQual', 'Neighborhood_BrkSide', 'MSSubClass_50.0', 'Exterior1st_MetalSd', 'Neighborhood_Somerst', 'Exterior2nd_MetalSd', 'Neighborhood_NAmes', 'Alley_Grvl', 'SaleCondition_Abnorml', 'Foundation_Slab', 'GarageCond', 'Neighborhood_MeadowV', 'Heating_Grav', 'EnclosedPorch', 'LotConfig_CulDSac', 'KitchenAbvGr', 'Exterior1st_AsbShng', 'Neighborhood_Timber', 'Functional', 'Heating_GasA', 'Exterior2nd_AsbShng', 'BldgType_1Fam', 'Alley_nan', 'Condition1_Artery', 'Neighborhood_BrDale', 'LotShape_IR2', 'Condition1_Feedr', 'Neighborhood_Sawyer', 'BsmtFinType2', 'ScreenPorch', 'MSZoning_FV', 'RoofMatl_WdShngl', 'Condition1_Norm', 'Neighborhood_CollgCr', 'MSSubClass_90.0', 'BldgType_Duplex', 'MSSubClass_160.0', 'LandContour_Bnk', 'LandContour_HLS', 'BldgType_2fmCon', 'BldgType_Twnhs', 'MSSubClass_180.0', 'HouseStyle_1.5Unf', 'MSSubClass_190.0', 'SaleCondition_Normal', 'MSSubClass_45.0', 'HouseStyle_SFoyer', 'PavedDrive_P', 'Exterior1st_CemntBd', 'MSSubClass_120.0', 'Exterior2nd_CmentBd', 'Fence', 'RoofMatl_CompShg', 'LotConfig_Inside', 'Neighborhood_Crawfor', 'GarageType_CarPort', 'SaleType_COD', 'Exterior1st_BrkComm', 'Neighborhood_Gilbert', 'Heating_Wall', 'MiscFeature_nan', 'Exterior1st_HdBoard', 'HouseStyle_1Story', 'Neighborhood_ClearCr', 'MiscFeature_Shed', 'MSZoning_RH', 'Neighborhood_Veenker', 'PoolQC_NA', 'PoolArea', 'SaleCondition_AdjLand', 'MiscFeature_Othr', 'Condition1_PosN', 'Neighborhood_SWISU', 'Neighborhood_NWAmes', 'Exterior1st_WdShing', 'Exterior2nd_Stucco', 'Street_Grvl', 'Street_Pave', 'MoSold', 'Exterior2nd_Brk Cmn', 'Condition2_Feedr', 'MasVnrType_nan', '3SsnPorch', 'MSSubClass_20.0', 'Condition2_RRNn', 'Heating_Floor', 'Exterior2nd_Wd Shng', 'RoofMatl_WdShake', 'Condition1_PosA', 'Exterior2nd_HdBoard', 'SaleType_ConLD', 'RoofStyle_Gambrel', 'ExterCond', 'SaleCondition_Family', 'Condition2_Norm', 'Exterior2nd_ImStucc', 'Condition1_RRAe', 'Condition2_PosA', 'Exterior1st_Stucco', 'MasVnrType_BrkCmn', 'Condition2_PosN', 'SaleType_Con', 'Exterior2nd_Other', 'Condition2_Artery', 'Neighborhood_Mitchel', 'Exterior1st_Stone', 'SaleType_Oth', 'Neighborhood_Blmngtn', 'LandContour_Low', 'LowQualFinSF', 'MSSubClass_85.0', 'LotShape_IR3', 'SaleType_ConLw', 'YrSold', 'OverallCond', 'LandSlope_Gtl', 'PoolQC', 'MoSold_sin', 'Neighborhood_SawyerW', 'Exterior1st_AsphShn', 'HouseStyle_2.5Fin', 'MSSubClass_70.0', 'Neighborhood_NPkVill', 'GarageType_Basment', 'Exterior1st_CBlock', 'Exterior2nd_CBlock', 'Exterior1st_BrkFace', 'Exterior1st_ImStucc', 'LandSlope_Mod', 'RoofStyle_Shed', 'MiscFeature_TenC', 'Heating_OthW', 'Heating_GasW', 'BldgType_TwnhsE', 'LandSlope_Sev', 'HouseStyle_2.5Unf', 'SaleCondition_Alloca', 'Exterior2nd_AsphShn', 'RoofMatl_Membran', 'Exterior2nd_Plywood', 'RoofStyle_Flat', 'SaleType_CWD ...

# %% [markdown]
# ### TSNE, PCA and KmEANS
#
# TSNE is a tool to visualize high-dimensional data. It converts similarities between data points to joint probabilities and tries to minimize the Kullback-Leibler divergence between the joint probabilities of the low-dimensional embedding and the high-dimensional data. It is recommended to use a dimensionality reduction method like PCA to reduce the number of dimensions to a reasonable amount to plot. Finally KMeans algorithm will help us to split our PCA components into five clusters according to the target (Sale Price).

# %%
# StandardScaler from Scikit-Learn
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

features = [f for f in train_df.columns]
model = TSNE(n_components=2, random_state=0, perplexity=50)
X = train_df[features].fillna(0.).values
tsne = model.fit_transform(X)

std = StandardScaler()
s = std.fit_transform(X)
pca = PCA(n_components=8)
pca.fit(s)
pc = pca.transform(s)
kmeans = KMeans(n_clusters=5)
kmeans.fit(pc)

fr = pd.DataFrame({'tsne1': tsne[:,0], 'tsne2': tsne[:, 1], 'cluster': kmeans.labels_})
sns.lmplot(data=fr, x='tsne1', y='tsne2', hue='cluster', fit_reg=False)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.22716886676201248

# %% [raw]
# First 8 PCA Components explain 22% of variance. There seems to be some clustering present but it is not enough for representing most data information.

# %%
import numpy as np
# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline 

# Cumulative explained variance
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot cumulative explained variance
plt.plot(range(len(cumulative_explained_variance)), cumulative_explained_variance)

# %% [markdown]
# ### Data Wrangling
#
# Now lets try drop categories with weak correlation to SalePrice

# %%
train_df_less_weak_cat = train_df.copy()
test_df_less_weak_cat = test_df.copy()
for df in [train_df_less_weak_cat]:
    df.drop(cols_bel_corr_limit, inplace= True, axis = 1)

# %%
features = [f for f in train_df_less_weak_cat.columns]
model = TSNE(n_components=2, random_state=0, perplexity=50)
X = train_df_less_weak_cat[features].fillna(0.).values
tsne = model.fit_transform(X)

std = StandardScaler()
s = std.fit_transform(X)
pca = PCA(n_components=8)
pca.fit(s)
pc = pca.transform(s)
kmeans = KMeans(n_clusters=5)
kmeans.fit(pc)

fr = pd.DataFrame({'tsne1': tsne[:,0], 'tsne2': tsne[:, 1], 'cluster': kmeans.labels_})
sns.lmplot(data=fr, x='tsne1', y='tsne2', hue='cluster', fit_reg=False)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.9842943637939534

# %% [markdown]
# After dropping weakly correlated categories our 8 PCA Components explain 98% of variance.

# %%
import numpy as np
# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline 

# Cumulative explained variance
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot cumulative explained variance
plt.plot(range(len(cumulative_explained_variance)), cumulative_explained_variance)

# %%
# Display explained variance ratio
pca.explained_variance_ratio_
# Out:
# array([0.64292724, 0.08796183, 0.07512266, 0.05872682, 0.04495904,
#        0.02802474, 0.02520401, 0.021368  ])
